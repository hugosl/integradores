# %%
from pylab import *
# %matplotlib inline

# %%
def euler(funcion,p_ini,t_final,h=0.01):
    tiempos = arange(p_ini[0],t_final+h,h)
    y = [0]*len(tiempos) #zeros len(tiempos) 
    y[0] = p_ini[1]
    for i in range(len(tiempos) - 1):
        y[i+1] = y[i] + funcion(y[i],tiempos[i])*h
    solucion = [tiempos,y]    
    return solucion

# %% [markdown]
# Esta es la ecuacion a resolver:

# %%
def mi_ec_diff(y,t):
    return y

# %%
sol = euler(mi_ec_diff,[0,1],3.,.001)
plot(sol[0],sol[1],sol[0],exp(sol[0])) 
show()

# %% [markdown]
#  Esta es la ecuacion diferencial a resolver:

# %%
def otra_func(y,t):
    return -y*t

# %%
sol = euler(otra_func,[0,1],3.,.001)
plot(sol[0],sol[1],sol[0],exp(-.5*sol[0]**2)) 
show()

# %%
def Erandi(f,x):
    return (1./(sin(x)+2))*(((2.*f)/sqrt(3))**2-1)

# %%
hs = [0.1,0.01,0.001,1e-3]
for h in hs:
    sol = euler(Erandi,[1,1],3.,h)
    plot(sol[0],sol[1]) 
show()

# %%
def segundo_orden(y,t):
    return array([y[1],-y[0]])

# %%
sol = euler(segundo_orden,[0,array([0,1])],200,0.0001)
#print sol[1]
y=zeros(len(sol[1]))
v=zeros(len(sol[1]))
print "datos que yo quiero"
for i in range(len(sol[1])):
    y[i] = sol[1][i][0]
    v[i] = sol[1][i][1]  
plot(sol[0],y) 
plot(sol[0],sin(sol[0])) 
#show()
# Out:
# datos que yo quiero

# %%
plot(y,v)
