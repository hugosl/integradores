# %%
from pylab import *
# %run 'mis_int.ipynb'
# %matplotlib inline

# %% [markdown]
# Hay que resolver $$\frac{d ^2 \vec \rho} {d \tau ^2} = -\frac{\hat \rho} {\rho ^2}$$

# %%
def mov_planeta(x,t):
    r3 = (x[0]**2 + x[1]**2)**(1.5)
    drx = x[2]
    dry = x[3]
    dvrx = -x[0]/r3
    dvry = -x[1]/r3
    return array([drx,dry,dvrx,dvry])
def J_mov_planeta(x,t):
    d_ec = array([0,0,0,0])
    r5 = (x[0]**2 + x[1]**2)**(2.5)
    rxmry = (2*x[0]*x[0] - x[1]*[1])/r5
    rxmrx = (2*x[1]*x[1] - x[0]*[0])/r5
    rxry = (3*x[0]*x[1])/r5
    Jac = array([[0,0,1,0],[0,0,0,1],[rxmry,rxry,0,0],[rxry,rxmrx,0,0]])
    return

# %%
# %%time
t,r_vr = rk2(mov_planeta,[1,0,.6,.9],[0,10],0.01)
zoom = 2
xlim([-zoom,zoom]),ylim([-zoom,zoom])
axes().set_aspect('equal'),grid(True)
plot(r_vr[:,0],r_vr[:,1],'.')
show()
# Out:
# CPU times: user 115 ms, sys: 1.76 ms, total: 117 ms
# Wall time: 116 ms

# %%
t,r_vr = integra2(mov_planeta,J_mov_planeta,[1,0,.6,.9],[0,10],0.01)
zoom = 2
xlim([-zoom,zoom]),ylim([-zoom,zoom])
axes().set_aspect('equal'),grid(True)
plot(r_vr[:,0],r_vr[:,1],'.')
show()
# Out:
# /home/est5/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:11: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/est5/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:12: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-9a1b1a4209fb> in <module>()
# ----> 1 t,r_vr = integra2(mov_planeta,J_mov_planeta,[1,0,.6,.9],[0,10],0.01)
#       2 zoom = 2
#       3 xlim([-zoom,zoom]),ylim([-zoom,zoom])
#       4 axes().set_aspect('equal'),grid(True)
#       5 plot(r_vr[:,0],r_vr[:,1],'.')
#
# <ipython-input-4-a1b8bfbfc4bc> in integra2(ec, d_ec, p_ini, x, h)
#       5     for i in xrange(len(tiempos)-1):
#       6         f = ec(sol[i,:],tiempos[i])
# ----> 7         df,jac=d_ec(sol[i,:],tiempos[i])
#       8         sol[i+1,:]=sol[i,:]+h*f+(0.5*h*h*(df+dot(jac,f)))
#       9     return tiempos,sol
#
# <ipython-input-30-a937c6e42331> in J_mov_planeta(x, t)
#      12     rxmrx = (2*x[1]*x[1] - x[0]*[0])/r5
#      13     rxry = (3*x[0]*x[1])/r5
# ---> 14     Jac = array([0,0,1,0],[0,0,0,1],[rxmry,rxry,0,0],[rxry,rxmrx,0,0])
#      15     return
#
# ValueError: only 2 non-keyword arguments accepted

# %%
t,r_vr = rk2(mov_planeta,[1,0,.6,.9],[0,10],0.01)
zoom = 2
xlim([-zoom,zoom]),ylim([-zoom,zoom])
axes().set_aspect('equal'),grid(True)
plot(r_vr[:,0],r_vr[:,1],'.')
show()

# %%
from scipy.integrate import *
h=0.1
tiempos = arange(0,10+h,h)

# %%
# %%time
r_vr = odeint(mov_planeta,[1,0,.6,.9],tiempos)
zoom = 2
xlim([-zoom,zoom]),ylim([-zoom,zoom])
axes().set_aspect('equal'),grid(True)
plot(r_vr[:,0],r_vr[:,1])
show()
# Out:
# CPU times: user 109 ms, sys: 1.64 ms, total: 111 ms
# Wall time: 110 ms

# %%
zoom = 2
xlim([-zoom,zoom]),ylim([-zoom,zoom])
axes().set_aspect('equal'),grid(True)
plot(r_vr[:,2],r_vr[:,3])
show()
